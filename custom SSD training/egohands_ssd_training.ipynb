# %% [markdown]
# Attempt to train customized version of SSD for cropping image down to focus the hand.

# %%
import os
import urllib.request

# %%
urllib.request.urlretrieve('http://vision.soic.indiana.edu/egohands_files/egohands_data.zip', 'egohands_data.zip')
# Out:
# ('egohands_data.zip', <http.client.HTTPMessage at 0x7f6852bf0f40>)

# %%
import scipy.io as sio
import numpy as np
import os
import gc
import six.moves.urllib as urllib
import cv2
import time
import xml.etree.cElementTree as ET
import random
import shutil as sh
from shutil import copyfile
import zipfile
from google.colab.patches import cv2_imshow
import csv


def save_csv(csv_path, csv_content):
    with open(csv_path, 'w') as csvfile:
        wr = csv.writer(csvfile)
        for i in range(len(csv_content)):
            wr.writerow(csv_content[i])


def get_bbox_visualize(base_path, dir):
    image_path_array = []
    for root, dirs, filenames in os.walk(base_path + dir):
        for f in filenames:
            if(f.split(".")[1] == "jpg"):
                img_path = base_path + dir + "/" + f
                image_path_array.append(img_path)

    #sort image_path_array to ensure its in the low to high order expected in polygon.mat
    image_path_array.sort()
    boxes = sio.loadmat(
        base_path + dir + "/polygons.mat")
    # there are 100 of these per folder in the egohands dataset
    polygons = boxes["polygons"][0]
    # first = polygons[0]
    # print(len(first))
    pointindex = 0

    for first in polygons:
        index = 0

        font = cv2.FONT_HERSHEY_SIMPLEX

        img_id = image_path_array[pointindex]
        img = cv2.imread(img_id)

        img_params = {}
        img_params["width"] = np.size(img, 1)
        img_params["height"] = np.size(img, 0)
        head, tail = os.path.split(img_id)
        img_params["filename"] = tail
        img_params["path"] = os.path.abspath(img_id)
        img_params["type"] = "train"
        pointindex += 1

        boxarray = []
        csvholder = []
        for pointlist in first:
            pst = np.empty((0, 2), int)
            max_x = max_y = min_x = min_y = height = width = 0

            findex = 0
            for point in pointlist:
                if(len(point) == 2):
                    x = int(point[0])
                    y = int(point[1])

                    if(findex == 0):
                        min_x = x
                        min_y = y
                    findex += 1
                    max_x = x if (x > max_x) else max_x
                    min_x = x if (x < min_x) else min_x
                    max_y = y if (y > max_y) else max_y
                    min_y = y if (y < min_y) else min_y
                    # print(index, "====", len(point))
                    appeno = np.array([[x, y]])
                    pst = np.append(pst, appeno, axis=0)
                    cv2.putText(img, ".", (x, y), font, 0.7,
                                (255, 255, 255), 2, cv2.LINE_AA)

            hold = {}
            hold['minx'] = min_x
            hold['miny'] = min_y
            hold['maxx'] = max_x
            hold['maxy'] = max_y
            if (min_x > 0 and min_y > 0 and max_x > 0 and max_y > 0):
                boxarray.append(hold)
                labelrow = [tail,
                            np.size(img, 1), np.size(img, 0), "hand", min_x, min_y, max_x, max_y]
                csvholder.append(labelrow)

            cv2.polylines(img, [pst], True, (0, 255, 255), 1)
            cv2.rectangle(img, (min_x, max_y),
                          (max_x, min_y), (0, 255, 0), 1)

        csv_path = img_id.split(".")[0]
        if not os.path.exists(csv_path + ".csv"):
            cv2.putText(img, "DIR : " + dir + " - " + tail, (20, 50),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.75, (77, 255, 9), 2)
            #cv2_imshow('Verifying annotation ', img)
            save_csv(csv_path + ".csv", csvholder)
            #print("===== saving csv file for ", tail)
        cv2.waitKey(2)  # close window when a key press is detected


def create_directory(dir_path):
    if not os.path.exists(dir_path):
        os.makedirs(dir_path)

# combine all individual csv files for each image into a single csv file per folder.


def generate_label_files(image_dir):
    header = ['filename', 'width', 'height',
              'class', 'xmin', 'ymin', 'xmax', 'ymax']
    for root, dirs, filenames in os.walk(image_dir):
        for dir in dirs:
            csvholder = []
            csvholder.append(header)
            loop_index = 0
            for f in os.listdir(image_dir + dir):
                if(f.split(".")[1] == "csv"):
                    loop_index += 1
                    #print(loop_index, f)
                    csv_file = open(image_dir + dir + "/" + f, 'r')
                    reader = csv.reader(csv_file)
                    for row in reader:
                        csvholder.append(row)
                    csv_file.close()
                    os.remove(image_dir + dir + "/" + f)
            save_csv(image_dir + dir + "/" + dir + "_labels.csv", csvholder)
            print("Saved label csv for ", dir, image_dir +
                  dir + "/" + dir + "_labels.csv")


# Split data, copy to train/test folders
def split_data_test_eval_train(image_dir):
    create_directory("images")
    create_directory("images/train")
    create_directory("images/test")

    data_size = 4000
    loop_index = 0
    data_sampsize = int(0.1 * data_size)
    test_samp_array = random.sample(range(data_size), k=data_sampsize)

    for root, dirs, filenames in os.walk(image_dir):
        for dir in dirs:
            for f in os.listdir(image_dir + dir):
                if(f.split(".")[1] == "jpg"):
                    loop_index += 1
                    print(loop_index, f)

                    if loop_index in test_samp_array:
                        os.rename(image_dir + dir +
                                  "/" + f, "images/test/" + f)
                        os.rename(image_dir + dir +
                                  "/" + f.split(".")[0] + ".csv", "images/test/" + f.split(".")[0] + ".csv")
                    else:
                        os.rename(image_dir + dir +
                                  "/" + f, "images/train/" + f)
                        os.rename(image_dir + dir +
                                  "/" + f.split(".")[0] + ".csv", "images/train/" + f.split(".")[0] + ".csv")
                    print(loop_index, image_dir + f)
            print(">   done scanning director ", dir)
            os.remove(image_dir + dir + "/polygons.mat")
            os.rmdir(image_dir + dir)

        print("Train/test content generation complete!")
        generate_label_files("images/")


def generate_csv_files(image_dir):
    for root, dirs, filenames in os.walk(image_dir):
        for dir in dirs:
            get_bbox_visualize(image_dir, dir)

    print("CSV generation complete!\nGenerating train/test/eval folders")
    split_data_test_eval_train("egohands/_LABELLED_SAMPLES/")


# rename image files so we can have them all in a train/test/eval folder.
def rename_files(image_dir):
    print("Renaming files")
    loop_index = 0
    for root, dirs, filenames in os.walk(image_dir):
        for dir in dirs:
            for f in os.listdir(image_dir + dir):
                if (dir not in f):
                    if(f.split(".")[1] == "jpg"):
                        loop_index += 1
                        os.rename(image_dir + dir +
                                  "/" + f, image_dir + dir +
                                  "/" + dir + "_" + f)
                else:
                    break

    generate_csv_files("egohands/_LABELLED_SAMPLES/")

def extract_folder(dataset_path):
    print("Egohands dataset already downloaded.\nGenerating CSV files")
    if not os.path.exists("egohands"):
        zip_ref = zipfile.ZipFile(dataset_path, 'r')
        print("> Extracting Dataset files")
        zip_ref.extractall("egohands")
        print("> Extraction complete")
        zip_ref.close()
        rename_files("egohands/_LABELLED_SAMPLES/")

def download_egohands_dataset(dataset_url, dataset_path):
    is_downloaded = os.path.exists(dataset_path)
    if not is_downloaded:
        print(
            "> downloading egohands dataset. This may take a while (1.3GB, say 3-5mins). Coffee break?")
        opener = urllib.request.URLopener()
        opener.retrieve(dataset_url, dataset_path)
        print("> download complete")
        extract_folder(dataset_path);

    else:
        extract_folder(dataset_path)


EGOHANDS_DATASET_URL = "http://vision.soic.indiana.edu/egohands_files/egohands_data.zip"
EGO_HANDS_FILE = "egohands_data.zip"


download_egohands_dataset(EGOHANDS_DATASET_URL, EGO_HANDS_FILE)

# %%
# !pip install object-detection

# %%
# %cd /content
# !python generate_tfrecord.py --csv_input=/content/images/train/train_labels.csv --output_path=train.record --image_dir=/content/images/train
# !python generate_tfrecord.py --csv_input=/content/images/test/test_labels.csv --output_path=test.record --image_dir=/content/images/test

# %%
# !wget http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz
# !wget http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Out:
# --2023-11-08 18:53:11--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 74.125.200.207, 74.125.130.207, 74.125.68.207, ...
# Connecting to download.tensorflow.org (download.tensorflow.org)|74.125.200.207|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20515344 (20M) [application/x-tar]
# Saving to: ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’
#
# ssd_mobilenet_v2_fp 100%[===================>]  19.56M  9.90MB/s    in 2.0s
#
# 2023-11-08 18:53:13 (9.90 MB/s) - ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’ saved [20515344/20515344]

# %%
# !mkdir /content/mainmodel
# !mv /content/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz /content/mainmodel
# !tar -xf /content/mainmodel/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz -C /content/mainmodel/
# !mv -f /content/pipeline.config /content/mainmodel/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config
# !mv /content/mainmodel/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint /content/mainmodel/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint0

# %%
# %cd /content
# !git clone https://github.com/tensorflow/models.git
# Out:
# /content
# Cloning into 'models'...
# remote: Enumerating objects: 89661, done.
# remote: Counting objects: 100% (3369/3369), done.
# remote: Compressing objects: 100% (1813/1813), done.
# remote: Total 89661 (delta 1752), reused 3081 (delta 1526), pack-reused 86292
# Receiving objects: 100% (89661/89661), 605.15 MiB | 15.77 MiB/s, done.
# Resolving deltas: 100% (63663/63663), done.

# %%
# %cd /content/models/research
# !protoc object_detection/protos/*.proto --python_out=. --proto_path=/content/models/research/
# !cp -r -T /content/models/research/object_detection /usr/local/lib/python3.10/dist-packages/object_detection
# !mv -f /content/tfexample_decoder.py /usr/local/lib/python3.10/dist-packages/tf_slim/data/tfexample_decoder.py
# Out:
# /content/models/research

# %%
# !pip install tensorflow-io
# !pip install tf-models-official
# !pip install lvis
# !pip install tensorflow==2.13.0

# %%
# !python3 /content/models/research/slim/setup.py build
# !python3 /content/models/research/slim/setup.py install

# %%
os.environ['PYTHONPATH'] += ':/content/models/research/:/content/models/research/slim/'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -rf /content/drive/MyDrive/obj_detection_training/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint /content/mainmodel/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/checkpoint

# %%
# !cp /content/drive/MyDrive/obj_detection_training/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/ckpt-386.data-00000-of-00001 /content/mainmodel/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-386.data-00000-of-00001
# !cp /content/drive/MyDrive/obj_detection_training/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/ckpt-386.index /content/mainmodel/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-386.index

# %%
# !rm /content/mainmodel/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-361.data-00000-of-00001
# !rm /content/mainmodel/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-361.index

# %%
# !python3 /content/models/research/object_detection/legacy/train.py --logtostderr --train_dir=/content/images/ --pipeline_config_path=/content/mainmodel/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config
# !python3 /content/models/research/object_detection/model_main_tf2.py --alsologtostderr --model_dir=/content/drive/MyDrive/obj_detection_training/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/ --pipeline_config_path=/content/mainmodel/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config --num_train_steps=200000 --checkpoint_every_n=500 #--use_tpu=true
# Out:
# 2023-11-08 18:56:03.273511: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-08 18:56:03.273561: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-08 18:56:03.273604: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-08 18:56:03.284253: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-08 18:56:04.952016: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-11-08 18:56:09.120834: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-08 18:56:09.152698: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-08 18:56:09.152986: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-08 18:56:09.154073: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-08 18:56:09.154341: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-08 18:56:09.154538: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-08 18:56:11.605431: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-08 18:56:11.605730: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-08 18:56:11.605867: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-11-08 18:56:11.605967: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-08 18:56:11.606107: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13692 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I1108 18:56:11.606929 137794023396480 mirrored_strategy.py:423] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 200000
# I1108 18:56:11.632242 137794023396480 config_util.py:552] Maybe overwriting train_steps: 200000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I1108 18:56:11.632436 137794023396480 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /content/models/research/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W1108 18:56:11.659268 137794023396480 deprecation.py:50] From /content/models/research/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['/content/train.record']
# I1108 18:56:11.665338 137794023396480 dataset_builder.py:162] Reading unweighted datasets: ['/content/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['/content/train.record']
# I1108 18:56:11.665508 137794023396480 dataset_builder.py:79] Reading record datasets for input file: ['/content/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I1108 18:56:11.665589 137794023396480 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W1108 18:56:11.665658 137794023396480 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /content/models/research/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W1108 18:56:11.671973 137794023396480 deprecation.py:50] From /content/models/research/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /content/models/research/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W1108 18:56:11.691524 137794023396480 deprecation.py:50] From /content/models/research/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1260: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W1108 18:56:18.019713 137794023396480 deprecation.py:50] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1260: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1260: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W1108 18:56:22.402068 137794023396480 deprecation.py:50] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1260: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1260: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1108 18:56:24.933261 137794023396480 deprecation.py:50] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1260: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# I1108 18:56:38.524982 137789271905856 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I1108 18:56:53.259976 137789271905856 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# 2023-11-08 18:57:07.386426: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8900
# I1108 18:57:19.629833 137789362386496 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I1108 18:57:30.711046 137789362386496 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I1108 18:57:40.920610 137789362386496 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I1108 18:57:51.239737 137789362386496 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# INFO:tensorflow:Step 187600 per-step time 1.007s
# I1108 18:58:57.909530 137794023396480 model_lib_v2.py:705] Step 187600 per-step time 1.007s
# INFO:tensorflow:{'Loss/classification_loss': 0.021725554,
#  'Loss/localization_loss': 0.0048930547,
#  'Loss/regularization_loss': 0.024246003,
#  'Loss/total_loss': 0.050864615,
#  'learning_rate': 0.00076397654}
# I1108 18:58:57.909964 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.021725554,
#  'Loss/localization_loss': 0.0048930547,
#  'Loss/regularization_loss': 0.024246003,
#  'Loss/total_loss': 0.050864615,
#  'learning_rate': 0.00076397654}
# INFO:tensorflow:Step 187700 per-step time 0.393s
# I1108 18:59:37.169210 137794023396480 model_lib_v2.py:705] Step 187700 per-step time 0.393s
# INFO:tensorflow:{'Loss/classification_loss': 0.048915744,
#  'Loss/localization_loss': 0.013742609,
#  'Loss/regularization_loss': 0.02424458,
#  'Loss/total_loss': 0.08690293,
#  'learning_rate': 0.00075174094}
# I1108 18:59:37.169626 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.048915744,
#  'Loss/localization_loss': 0.013742609,
#  'Loss/regularization_loss': 0.02424458,
#  'Loss/total_loss': 0.08690293,
#  'learning_rate': 0.00075174094}
# INFO:tensorflow:Step 187800 per-step time 0.377s
# I1108 19:00:14.894822 137794023396480 model_lib_v2.py:705] Step 187800 per-step time 0.377s
# INFO:tensorflow:{'Loss/classification_loss': 0.027588757,
#  'Loss/localization_loss': 0.0050682267,
#  'Loss/regularization_loss': 0.024243185,
#  'Loss/total_loss': 0.056900166,
#  'learning_rate': 0.0007396054}
# I1108 19:00:14.895200 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.027588757,
#  'Loss/localization_loss': 0.0050682267,
#  'Loss/regularization_loss': 0.024243185,
#  'Loss/total_loss': 0.056900166,
#  'learning_rate': 0.0007396054}
# INFO:tensorflow:Step 187900 per-step time 0.373s
# I1108 19:00:52.225246 137794023396480 model_lib_v2.py:705] Step 187900 per-step time 0.373s
# INFO:tensorflow:{'Loss/classification_loss': 0.02179401,
#  'Loss/localization_loss': 0.0061192387,
#  'Loss/regularization_loss': 0.024241807,
#  'Loss/total_loss': 0.052155055,
#  'learning_rate': 0.00072756765}
# I1108 19:00:52.225718 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.02179401,
#  'Loss/localization_loss': 0.0061192387,
#  'Loss/regularization_loss': 0.024241807,
#  'Loss/total_loss': 0.052155055,
#  'learning_rate': 0.00072756765}
# INFO:tensorflow:Step 188000 per-step time 0.397s
# I1108 19:01:31.863430 137794023396480 model_lib_v2.py:705] Step 188000 per-step time 0.397s
# INFO:tensorflow:{'Loss/classification_loss': 0.021939108,
#  'Loss/localization_loss': 0.004522663,
#  'Loss/regularization_loss': 0.024240455,
#  'Loss/total_loss': 0.050702225,
#  'learning_rate': 0.0007156276}
# I1108 19:01:31.863790 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.021939108,
#  'Loss/localization_loss': 0.004522663,
#  'Loss/regularization_loss': 0.024240455,
#  'Loss/total_loss': 0.050702225,
#  'learning_rate': 0.0007156276}
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1108 19:01:32.087579 137794023396480 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1108 19:01:32.090341 137794023396480 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1108 19:01:32.091652 137794023396480 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1108 19:01:32.092766 137794023396480 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1108 19:01:32.098044 137794023396480 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1108 19:01:32.099661 137794023396480 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1108 19:01:32.101659 137794023396480 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1108 19:01:32.102793 137794023396480 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1108 19:01:32.109251 137794023396480 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1108 19:01:32.110702 137794023396480 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Step 188100 per-step time 0.386s
# I1108 19:02:10.464948 137794023396480 model_lib_v2.py:705] Step 188100 per-step time 0.386s
# INFO:tensorflow:{'Loss/classification_loss': 0.027116973,
#  'Loss/localization_loss': 0.006167013,
#  'Loss/regularization_loss': 0.024239128,
#  'Loss/total_loss': 0.057523116,
#  'learning_rate': 0.000703783}
# I1108 19:02:10.465364 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.027116973,
#  'Loss/localization_loss': 0.006167013,
#  'Loss/regularization_loss': 0.024239128,
#  'Loss/total_loss': 0.057523116,
#  'learning_rate': 0.000703783}
# INFO:tensorflow:Step 188200 per-step time 0.367s
# I1108 19:02:47.161813 137794023396480 model_lib_v2.py:705] Step 188200 per-step time 0.367s
# INFO:tensorflow:{'Loss/classification_loss': 0.025056854,
#  'Loss/localization_loss': 0.004038644,
#  'Loss/regularization_loss': 0.02423781,
#  'Loss/total_loss': 0.053333305,
#  'learning_rate': 0.0006920385}
# I1108 19:02:47.162170 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.025056854,
#  'Loss/localization_loss': 0.004038644,
#  'Loss/regularization_loss': 0.02423781,
#  'Loss/total_loss': 0.053333305,
#  'learning_rate': 0.0006920385}
# INFO:tensorflow:Step 188300 per-step time 0.397s
# I1108 19:03:26.871007 137794023396480 model_lib_v2.py:705] Step 188300 per-step time 0.397s
# INFO:tensorflow:{'Loss/classification_loss': 0.022191476,
#  'Loss/localization_loss': 0.008729595,
#  'Loss/regularization_loss': 0.024236504,
#  'Loss/total_loss': 0.055157576,
#  'learning_rate': 0.0006803918}
# I1108 19:03:26.871380 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.022191476,
#  'Loss/localization_loss': 0.008729595,
#  'Loss/regularization_loss': 0.024236504,
#  'Loss/total_loss': 0.055157576,
#  'learning_rate': 0.0006803918}
# INFO:tensorflow:Step 188400 per-step time 0.376s
# I1108 19:04:04.483545 137794023396480 model_lib_v2.py:705] Step 188400 per-step time 0.376s
# INFO:tensorflow:{'Loss/classification_loss': 0.03157104,
#  'Loss/localization_loss': 0.0069415923,
#  'Loss/regularization_loss': 0.024235224,
#  'Loss/total_loss': 0.06274786,
#  'learning_rate': 0.00066884275}
# I1108 19:04:04.483930 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.03157104,
#  'Loss/localization_loss': 0.0069415923,
#  'Loss/regularization_loss': 0.024235224,
#  'Loss/total_loss': 0.06274786,
#  'learning_rate': 0.00066884275}
# INFO:tensorflow:Step 188500 per-step time 0.389s
# I1108 19:04:43.393628 137794023396480 model_lib_v2.py:705] Step 188500 per-step time 0.389s
# INFO:tensorflow:{'Loss/classification_loss': 0.045436952,
#  'Loss/localization_loss': 0.009404845,
#  'Loss/regularization_loss': 0.024233963,
#  'Loss/total_loss': 0.07907576,
#  'learning_rate': 0.00065739395}
# I1108 19:04:43.395030 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.045436952,
#  'Loss/localization_loss': 0.009404845,
#  'Loss/regularization_loss': 0.024233963,
#  'Loss/total_loss': 0.07907576,
#  'learning_rate': 0.00065739395}
# INFO:tensorflow:Step 188600 per-step time 0.410s
# I1108 19:05:24.363056 137794023396480 model_lib_v2.py:705] Step 188600 per-step time 0.410s
# INFO:tensorflow:{'Loss/classification_loss': 0.030214317,
#  'Loss/localization_loss': 0.0036582884,
#  'Loss/regularization_loss': 0.024232736,
#  'Loss/total_loss': 0.058105342,
#  'learning_rate': 0.0006460404}
# I1108 19:05:24.363464 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.030214317,
#  'Loss/localization_loss': 0.0036582884,
#  'Loss/regularization_loss': 0.024232736,
#  'Loss/total_loss': 0.058105342,
#  'learning_rate': 0.0006460404}
# INFO:tensorflow:Step 188700 per-step time 0.404s
# I1108 19:06:04.724021 137794023396480 model_lib_v2.py:705] Step 188700 per-step time 0.404s
# INFO:tensorflow:{'Loss/classification_loss': 0.026203386,
#  'Loss/localization_loss': 0.006112234,
#  'Loss/regularization_loss': 0.024231518,
#  'Loss/total_loss': 0.056547135,
#  'learning_rate': 0.0006347871}
# I1108 19:06:04.725562 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.026203386,
#  'Loss/localization_loss': 0.006112234,
#  'Loss/regularization_loss': 0.024231518,
#  'Loss/total_loss': 0.056547135,
#  'learning_rate': 0.0006347871}
# INFO:tensorflow:Step 188800 per-step time 0.383s
# I1108 19:06:43.085227 137794023396480 model_lib_v2.py:705] Step 188800 per-step time 0.383s
# INFO:tensorflow:{'Loss/classification_loss': 0.027716251,
#  'Loss/localization_loss': 0.0069625615,
#  'Loss/regularization_loss': 0.02423031,
#  'Loss/total_loss': 0.058909126,
#  'learning_rate': 0.0006236291}
# I1108 19:06:43.085790 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.027716251,
#  'Loss/localization_loss': 0.0069625615,
#  'Loss/regularization_loss': 0.02423031,
#  'Loss/total_loss': 0.058909126,
#  'learning_rate': 0.0006236291}
# INFO:tensorflow:Step 188900 per-step time 0.382s
# I1108 19:07:21.287509 137794023396480 model_lib_v2.py:705] Step 188900 per-step time 0.382s
# INFO:tensorflow:{'Loss/classification_loss': 0.02890719,
#  'Loss/localization_loss': 0.005020498,
#  'Loss/regularization_loss': 0.024229134,
#  'Loss/total_loss': 0.05815682,
#  'learning_rate': 0.0006125736}
# I1108 19:07:21.287879 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.02890719,
#  'Loss/localization_loss': 0.005020498,
#  'Loss/regularization_loss': 0.024229134,
#  'Loss/total_loss': 0.05815682,
#  'learning_rate': 0.0006125736}
# INFO:tensorflow:Step 189000 per-step time 0.393s
# I1108 19:08:00.549028 137794023396480 model_lib_v2.py:705] Step 189000 per-step time 0.393s
# INFO:tensorflow:{'Loss/classification_loss': 0.028372575,
#  'Loss/localization_loss': 0.007241961,
#  'Loss/regularization_loss': 0.024227982,
#  'Loss/total_loss': 0.05984252,
#  'learning_rate': 0.0006016135}
# I1108 19:08:00.549549 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.028372575,
#  'Loss/localization_loss': 0.007241961,
#  'Loss/regularization_loss': 0.024227982,
#  'Loss/total_loss': 0.05984252,
#  'learning_rate': 0.0006016135}
# INFO:tensorflow:Step 189100 per-step time 0.421s
# I1108 19:08:42.599889 137794023396480 model_lib_v2.py:705] Step 189100 per-step time 0.421s
# INFO:tensorflow:{'Loss/classification_loss': 0.024034018,
#  'Loss/localization_loss': 0.0050859214,
#  'Loss/regularization_loss': 0.024226846,
#  'Loss/total_loss': 0.053346783,
#  'learning_rate': 0.0005907488}
# I1108 19:08:42.600269 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.024034018,
#  'Loss/localization_loss': 0.0050859214,
#  'Loss/regularization_loss': 0.024226846,
#  'Loss/total_loss': 0.053346783,
#  'learning_rate': 0.0005907488}
# INFO:tensorflow:Step 189200 per-step time 0.403s
# I1108 19:09:22.938056 137794023396480 model_lib_v2.py:705] Step 189200 per-step time 0.403s
# INFO:tensorflow:{'Loss/classification_loss': 0.03631633,
#  'Loss/localization_loss': 0.006529631,
#  'Loss/regularization_loss': 0.024225743,
#  'Loss/total_loss': 0.067071706,
#  'learning_rate': 0.00057998893}
# I1108 19:09:22.938468 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.03631633,
#  'Loss/localization_loss': 0.006529631,
#  'Loss/regularization_loss': 0.024225743,
#  'Loss/total_loss': 0.067071706,
#  'learning_rate': 0.00057998893}
# INFO:tensorflow:Step 189300 per-step time 0.358s
# I1108 19:09:58.862291 137794023396480 model_lib_v2.py:705] Step 189300 per-step time 0.358s
# INFO:tensorflow:{'Loss/classification_loss': 0.025117418,
#  'Loss/localization_loss': 0.0038628697,
#  'Loss/regularization_loss': 0.024224665,
#  'Loss/total_loss': 0.053204954,
#  'learning_rate': 0.0005693221}
# I1108 19:09:58.862694 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.025117418,
#  'Loss/localization_loss': 0.0038628697,
#  'Loss/regularization_loss': 0.024224665,
#  'Loss/total_loss': 0.053204954,
#  'learning_rate': 0.0005693221}
# INFO:tensorflow:Step 189400 per-step time 0.395s
# I1108 19:10:38.250783 137794023396480 model_lib_v2.py:705] Step 189400 per-step time 0.395s
# INFO:tensorflow:{'Loss/classification_loss': 0.026609374,
#  'Loss/localization_loss': 0.006793194,
#  'Loss/regularization_loss': 0.02422359,
#  'Loss/total_loss': 0.057626158,
#  'learning_rate': 0.00055875536}
# I1108 19:10:38.251446 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.026609374,
#  'Loss/localization_loss': 0.006793194,
#  'Loss/regularization_loss': 0.02422359,
#  'Loss/total_loss': 0.057626158,
#  'learning_rate': 0.00055875536}
# INFO:tensorflow:Step 189500 per-step time 0.400s
# I1108 19:11:18.238360 137794023396480 model_lib_v2.py:705] Step 189500 per-step time 0.400s
# INFO:tensorflow:{'Loss/classification_loss': 0.02644172,
#  'Loss/localization_loss': 0.005402492,
#  'Loss/regularization_loss': 0.024222538,
#  'Loss/total_loss': 0.056066748,
#  'learning_rate': 0.0005482864}
# I1108 19:11:18.239272 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.02644172,
#  'Loss/localization_loss': 0.005402492,
#  'Loss/regularization_loss': 0.024222538,
#  'Loss/total_loss': 0.056066748,
#  'learning_rate': 0.0005482864}
# INFO:tensorflow:Step 189600 per-step time 0.405s
# I1108 19:11:58.716038 137794023396480 model_lib_v2.py:705] Step 189600 per-step time 0.405s
# INFO:tensorflow:{'Loss/classification_loss': 0.024626493,
#  'Loss/localization_loss': 0.0058636237,
#  'Loss/regularization_loss': 0.024221502,
#  'Loss/total_loss': 0.054711618,
#  'learning_rate': 0.0005379152}
# I1108 19:11:58.717777 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.024626493,
#  'Loss/localization_loss': 0.0058636237,
#  'Loss/regularization_loss': 0.024221502,
#  'Loss/total_loss': 0.054711618,
#  'learning_rate': 0.0005379152}
# INFO:tensorflow:Step 189700 per-step time 0.366s
# I1108 19:12:35.330784 137794023396480 model_lib_v2.py:705] Step 189700 per-step time 0.366s
# INFO:tensorflow:{'Loss/classification_loss': 0.025950978,
#  'Loss/localization_loss': 0.0062011806,
#  'Loss/regularization_loss': 0.024220495,
#  'Loss/total_loss': 0.05637265,
#  'learning_rate': 0.0005276441}
# I1108 19:12:35.331137 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.025950978,
#  'Loss/localization_loss': 0.0062011806,
#  'Loss/regularization_loss': 0.024220495,
#  'Loss/total_loss': 0.05637265,
#  'learning_rate': 0.0005276441}
# INFO:tensorflow:Step 189800 per-step time 0.404s
# I1108 19:13:15.667575 137794023396480 model_lib_v2.py:705] Step 189800 per-step time 0.404s
# INFO:tensorflow:{'Loss/classification_loss': 0.024833791,
#  'Loss/localization_loss': 0.0054138526,
#  'Loss/regularization_loss': 0.024219494,
#  'Loss/total_loss': 0.054467138,
#  'learning_rate': 0.0005174708}
# I1108 19:13:15.667973 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.024833791,
#  'Loss/localization_loss': 0.0054138526,
#  'Loss/regularization_loss': 0.024219494,
#  'Loss/total_loss': 0.054467138,
#  'learning_rate': 0.0005174708}
# INFO:tensorflow:Step 189900 per-step time 0.406s
# I1108 19:13:56.311424 137794023396480 model_lib_v2.py:705] Step 189900 per-step time 0.406s
# INFO:tensorflow:{'Loss/classification_loss': 0.022623694,
#  'Loss/localization_loss': 0.004952453,
#  'Loss/regularization_loss': 0.02421852,
#  'Loss/total_loss': 0.051794667,
#  'learning_rate': 0.00050739525}
# I1108 19:13:56.311984 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.022623694,
#  'Loss/localization_loss': 0.004952453,
#  'Loss/regularization_loss': 0.02421852,
#  'Loss/total_loss': 0.051794667,
#  'learning_rate': 0.00050739525}
# INFO:tensorflow:Step 190000 per-step time 0.404s
# I1108 19:14:36.743460 137794023396480 model_lib_v2.py:705] Step 190000 per-step time 0.404s
# INFO:tensorflow:{'Loss/classification_loss': 0.020744499,
#  'Loss/localization_loss': 0.0051231617,
#  'Loss/regularization_loss': 0.024217572,
#  'Loss/total_loss': 0.05008523,
#  'learning_rate': 0.00049741747}
# I1108 19:14:36.744144 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.020744499,
#  'Loss/localization_loss': 0.0051231617,
#  'Loss/regularization_loss': 0.024217572,
#  'Loss/total_loss': 0.05008523,
#  'learning_rate': 0.00049741747}
# INFO:tensorflow:Step 190100 per-step time 0.404s
# I1108 19:15:17.155401 137794023396480 model_lib_v2.py:705] Step 190100 per-step time 0.404s
# INFO:tensorflow:{'Loss/classification_loss': 0.027255278,
#  'Loss/localization_loss': 0.005365164,
#  'Loss/regularization_loss': 0.024216633,
#  'Loss/total_loss': 0.056837074,
#  'learning_rate': 0.00048753977}
# I1108 19:15:17.155806 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.027255278,
#  'Loss/localization_loss': 0.005365164,
#  'Loss/regularization_loss': 0.024216633,
#  'Loss/total_loss': 0.056837074,
#  'learning_rate': 0.00048753977}
# INFO:tensorflow:Step 190200 per-step time 0.381s
# I1108 19:15:55.203412 137794023396480 model_lib_v2.py:705] Step 190200 per-step time 0.381s
# INFO:tensorflow:{'Loss/classification_loss': 0.02048611,
#  'Loss/localization_loss': 0.0074571585,
#  'Loss/regularization_loss': 0.024215711,
#  'Loss/total_loss': 0.05215898,
#  'learning_rate': 0.00047775745}
# I1108 19:15:55.203808 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.02048611,
#  'Loss/localization_loss': 0.0074571585,
#  'Loss/regularization_loss': 0.024215711,
#  'Loss/total_loss': 0.05215898,
#  'learning_rate': 0.00047775745}
# INFO:tensorflow:Step 190300 per-step time 0.420s
# I1108 19:16:37.135093 137794023396480 model_lib_v2.py:705] Step 190300 per-step time 0.420s
# INFO:tensorflow:{'Loss/classification_loss': 0.025577398,
#  'Loss/localization_loss': 0.0063390005,
#  'Loss/regularization_loss': 0.02421481,
#  'Loss/total_loss': 0.056131206,
#  'learning_rate': 0.00046807766}
# I1108 19:16:37.135470 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.025577398,
#  'Loss/localization_loss': 0.0063390005,
#  'Loss/regularization_loss': 0.02421481,
#  'Loss/total_loss': 0.056131206,
#  'learning_rate': 0.00046807766}
# INFO:tensorflow:Step 190400 per-step time 0.418s
# I1108 19:17:18.928793 137794023396480 model_lib_v2.py:705] Step 190400 per-step time 0.418s
# INFO:tensorflow:{'Loss/classification_loss': 0.028354097,
#  'Loss/localization_loss': 0.007826627,
#  'Loss/regularization_loss': 0.024213929,
#  'Loss/total_loss': 0.060394652,
#  'learning_rate': 0.00045849322}
# I1108 19:17:18.929165 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.028354097,
#  'Loss/localization_loss': 0.007826627,
#  'Loss/regularization_loss': 0.024213929,
#  'Loss/total_loss': 0.060394652,
#  'learning_rate': 0.00045849322}
# INFO:tensorflow:Step 190500 per-step time 0.414s
# I1108 19:18:00.288430 137794023396480 model_lib_v2.py:705] Step 190500 per-step time 0.414s
# INFO:tensorflow:{'Loss/classification_loss': 0.023482235,
#  'Loss/localization_loss': 0.006524719,
#  'Loss/regularization_loss': 0.02421306,
#  'Loss/total_loss': 0.054220013,
#  'learning_rate': 0.0004490113}
# I1108 19:18:00.288827 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.023482235,
#  'Loss/localization_loss': 0.006524719,
#  'Loss/regularization_loss': 0.02421306,
#  'Loss/total_loss': 0.054220013,
#  'learning_rate': 0.0004490113}
# INFO:tensorflow:Step 190600 per-step time 0.419s
# I1108 19:18:42.223400 137794023396480 model_lib_v2.py:705] Step 190600 per-step time 0.419s
# INFO:tensorflow:{'Loss/classification_loss': 0.025452033,
#  'Loss/localization_loss': 0.004266383,
#  'Loss/regularization_loss': 0.02421222,
#  'Loss/total_loss': 0.053930636,
#  'learning_rate': 0.00043962238}
# I1108 19:18:42.223794 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.025452033,
#  'Loss/localization_loss': 0.004266383,
#  'Loss/regularization_loss': 0.02421222,
#  'Loss/total_loss': 0.053930636,
#  'learning_rate': 0.00043962238}
# INFO:tensorflow:Step 190700 per-step time 0.380s
# I1108 19:19:20.222254 137794023396480 model_lib_v2.py:705] Step 190700 per-step time 0.380s
# INFO:tensorflow:{'Loss/classification_loss': 0.024491655,
#  'Loss/localization_loss': 0.004727019,
#  'Loss/regularization_loss': 0.02421139,
#  'Loss/total_loss': 0.053430066,
#  'learning_rate': 0.000430336}
# I1108 19:19:20.222632 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.024491655,
#  'Loss/localization_loss': 0.004727019,
#  'Loss/regularization_loss': 0.02421139,
#  'Loss/total_loss': 0.053430066,
#  'learning_rate': 0.000430336}
# INFO:tensorflow:Step 190800 per-step time 0.405s
# I1108 19:20:00.671749 137794023396480 model_lib_v2.py:705] Step 190800 per-step time 0.405s
# INFO:tensorflow:{'Loss/classification_loss': 0.032328542,
#  'Loss/localization_loss': 0.0075686695,
#  'Loss/regularization_loss': 0.02421058,
#  'Loss/total_loss': 0.06410779,
#  'learning_rate': 0.00042114733}
# I1108 19:20:00.672144 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.032328542,
#  'Loss/localization_loss': 0.0075686695,
#  'Loss/regularization_loss': 0.02421058,
#  'Loss/total_loss': 0.06410779,
#  'learning_rate': 0.00042114733}
# INFO:tensorflow:Step 190900 per-step time 0.416s
# I1108 19:20:42.279401 137794023396480 model_lib_v2.py:705] Step 190900 per-step time 0.416s
# INFO:tensorflow:{'Loss/classification_loss': 0.028161343,
#  'Loss/localization_loss': 0.005142102,
#  'Loss/regularization_loss': 0.024209775,
#  'Loss/total_loss': 0.057513222,
#  'learning_rate': 0.0004120588}
# I1108 19:20:42.279937 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.028161343,
#  'Loss/localization_loss': 0.005142102,
#  'Loss/regularization_loss': 0.024209775,
#  'Loss/total_loss': 0.057513222,
#  'learning_rate': 0.0004120588}
# INFO:tensorflow:Step 191000 per-step time 0.406s
# I1108 19:21:22.810790 137794023396480 model_lib_v2.py:705] Step 191000 per-step time 0.406s
# INFO:tensorflow:{'Loss/classification_loss': 0.026782528,
#  'Loss/localization_loss': 0.0059595555,
#  'Loss/regularization_loss': 0.024209004,
#  'Loss/total_loss': 0.056951087,
#  'learning_rate': 0.00040306567}
# I1108 19:21:22.811157 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.026782528,
#  'Loss/localization_loss': 0.0059595555,
#  'Loss/regularization_loss': 0.024209004,
#  'Loss/total_loss': 0.056951087,
#  'learning_rate': 0.00040306567}
# INFO:tensorflow:Step 191100 per-step time 0.398s
# I1108 19:22:02.647371 137794023396480 model_lib_v2.py:705] Step 191100 per-step time 0.398s
# INFO:tensorflow:{'Loss/classification_loss': 0.028886238,
#  'Loss/localization_loss': 0.003667123,
#  'Loss/regularization_loss': 0.024208238,
#  'Loss/total_loss': 0.0567616,
#  'learning_rate': 0.00039417503}
# I1108 19:22:02.647748 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.028886238,
#  'Loss/localization_loss': 0.003667123,
#  'Loss/regularization_loss': 0.024208238,
#  'Loss/total_loss': 0.0567616,
#  'learning_rate': 0.00039417503}
# INFO:tensorflow:Step 191200 per-step time 0.383s
# I1108 19:22:40.989908 137794023396480 model_lib_v2.py:705] Step 191200 per-step time 0.383s
# INFO:tensorflow:{'Loss/classification_loss': 0.028045207,
#  'Loss/localization_loss': 0.0066338154,
#  'Loss/regularization_loss': 0.02420749,
#  'Loss/total_loss': 0.058886513,
#  'learning_rate': 0.0003853798}
# I1108 19:22:40.990288 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.028045207,
#  'Loss/localization_loss': 0.0066338154,
#  'Loss/regularization_loss': 0.02420749,
#  'Loss/total_loss': 0.058886513,
#  'learning_rate': 0.0003853798}
# INFO:tensorflow:Step 191300 per-step time 0.410s
# I1108 19:23:21.981398 137794023396480 model_lib_v2.py:705] Step 191300 per-step time 0.410s
# INFO:tensorflow:{'Loss/classification_loss': 0.02863178,
#  'Loss/localization_loss': 0.00680027,
#  'Loss/regularization_loss': 0.024206772,
#  'Loss/total_loss': 0.059638824,
#  'learning_rate': 0.00037668465}
# I1108 19:23:21.981871 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.02863178,
#  'Loss/localization_loss': 0.00680027,
#  'Loss/regularization_loss': 0.024206772,
#  'Loss/total_loss': 0.059638824,
#  'learning_rate': 0.00037668465}
# INFO:tensorflow:Step 191400 per-step time 0.405s
# I1108 19:24:02.443429 137794023396480 model_lib_v2.py:705] Step 191400 per-step time 0.405s
# INFO:tensorflow:{'Loss/classification_loss': 0.02611585,
#  'Loss/localization_loss': 0.008212107,
#  'Loss/regularization_loss': 0.024206055,
#  'Loss/total_loss': 0.05853401,
#  'learning_rate': 0.00036808968}
# I1108 19:24:02.443794 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.02611585,
#  'Loss/localization_loss': 0.008212107,
#  'Loss/regularization_loss': 0.024206055,
#  'Loss/total_loss': 0.05853401,
#  'learning_rate': 0.00036808968}
# INFO:tensorflow:Step 191500 per-step time 0.387s
# I1108 19:24:41.125095 137794023396480 model_lib_v2.py:705] Step 191500 per-step time 0.387s
# INFO:tensorflow:{'Loss/classification_loss': 0.02788736,
#  'Loss/localization_loss': 0.008121591,
#  'Loss/regularization_loss': 0.024205359,
#  'Loss/total_loss': 0.06021431,
#  'learning_rate': 0.00035959005}
# I1108 19:24:41.125530 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.02788736,
#  'Loss/localization_loss': 0.008121591,
#  'Loss/regularization_loss': 0.024205359,
#  'Loss/total_loss': 0.06021431,
#  'learning_rate': 0.00035959005}
# INFO:tensorflow:Step 191600 per-step time 0.408s
# I1108 19:25:21.938602 137794023396480 model_lib_v2.py:705] Step 191600 per-step time 0.408s
# INFO:tensorflow:{'Loss/classification_loss': 0.023974022,
#  'Loss/localization_loss': 0.0062207673,
#  'Loss/regularization_loss': 0.024204679,
#  'Loss/total_loss': 0.054399468,
#  'learning_rate': 0.00035119295}
# I1108 19:25:21.938982 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.023974022,
#  'Loss/localization_loss': 0.0062207673,
#  'Loss/regularization_loss': 0.024204679,
#  'Loss/total_loss': 0.054399468,
#  'learning_rate': 0.00035119295}
# INFO:tensorflow:Step 191700 per-step time 0.414s
# I1108 19:26:03.337762 137794023396480 model_lib_v2.py:705] Step 191700 per-step time 0.414s
# INFO:tensorflow:{'Loss/classification_loss': 0.021966653,
#  'Loss/localization_loss': 0.0050643487,
#  'Loss/regularization_loss': 0.024204018,
#  'Loss/total_loss': 0.05123502,
#  'learning_rate': 0.0003428912}
# I1108 19:26:03.338214 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.021966653,
#  'Loss/localization_loss': 0.0050643487,
#  'Loss/regularization_loss': 0.024204018,
#  'Loss/total_loss': 0.05123502,
#  'learning_rate': 0.0003428912}
# INFO:tensorflow:Step 191800 per-step time 0.420s
# I1108 19:26:45.313995 137794023396480 model_lib_v2.py:705] Step 191800 per-step time 0.420s
# INFO:tensorflow:{'Loss/classification_loss': 0.02734209,
#  'Loss/localization_loss': 0.009489571,
#  'Loss/regularization_loss': 0.024203362,
#  'Loss/total_loss': 0.061035022,
#  'learning_rate': 0.00033469198}
# I1108 19:26:45.314383 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.02734209,
#  'Loss/localization_loss': 0.009489571,
#  'Loss/regularization_loss': 0.024203362,
#  'Loss/total_loss': 0.061035022,
#  'learning_rate': 0.00033469198}
# INFO:tensorflow:Step 191900 per-step time 0.399s
# I1108 19:27:25.208733 137794023396480 model_lib_v2.py:705] Step 191900 per-step time 0.399s
# INFO:tensorflow:{'Loss/classification_loss': 0.02404089,
#  'Loss/localization_loss': 0.005864265,
#  'Loss/regularization_loss': 0.02420272,
#  'Loss/total_loss': 0.054107875,
#  'learning_rate': 0.00032658814}
# I1108 19:27:25.209169 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.02404089,
#  'Loss/localization_loss': 0.005864265,
#  'Loss/regularization_loss': 0.02420272,
#  'Loss/total_loss': 0.054107875,
#  'learning_rate': 0.00032658814}
# INFO:tensorflow:Step 192000 per-step time 0.383s
# I1108 19:28:03.522358 137794023396480 model_lib_v2.py:705] Step 192000 per-step time 0.383s
# INFO:tensorflow:{'Loss/classification_loss': 0.0236065,
#  'Loss/localization_loss': 0.004902156,
#  'Loss/regularization_loss': 0.0242021,
#  'Loss/total_loss': 0.052710757,
#  'learning_rate': 0.00031858683}
# I1108 19:28:03.522750 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.0236065,
#  'Loss/localization_loss': 0.004902156,
#  'Loss/regularization_loss': 0.0242021,
#  'Loss/total_loss': 0.052710757,
#  'learning_rate': 0.00031858683}
# INFO:tensorflow:Step 192100 per-step time 0.414s
# I1108 19:28:44.855560 137794023396480 model_lib_v2.py:705] Step 192100 per-step time 0.414s
# INFO:tensorflow:{'Loss/classification_loss': 0.027384702,
#  'Loss/localization_loss': 0.007432763,
#  'Loss/regularization_loss': 0.024201492,
#  'Loss/total_loss': 0.059018955,
#  'learning_rate': 0.00031068086}
# I1108 19:28:44.855935 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.027384702,
#  'Loss/localization_loss': 0.007432763,
#  'Loss/regularization_loss': 0.024201492,
#  'Loss/total_loss': 0.059018955,
#  'learning_rate': 0.00031068086}
# INFO:tensorflow:Step 192200 per-step time 0.408s
# I1108 19:29:25.636964 137794023396480 model_lib_v2.py:705] Step 192200 per-step time 0.408s
# INFO:tensorflow:{'Loss/classification_loss': 0.019650064,
#  'Loss/localization_loss': 0.0038130544,
#  'Loss/regularization_loss': 0.024200907,
#  'Loss/total_loss': 0.047664024,
#  'learning_rate': 0.00030287504}
# I1108 19:29:25.637362 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.019650064,
#  'Loss/localization_loss': 0.0038130544,
#  'Loss/regularization_loss': 0.024200907,
#  'Loss/total_loss': 0.047664024,
#  'learning_rate': 0.00030287504}
# INFO:tensorflow:Step 192300 per-step time 0.409s
# I1108 19:30:06.551872 137794023396480 model_lib_v2.py:705] Step 192300 per-step time 0.409s
# INFO:tensorflow:{'Loss/classification_loss': 0.030407999,
#  'Loss/localization_loss': 0.006403667,
#  'Loss/regularization_loss': 0.024200333,
#  'Loss/total_loss': 0.061012,
#  'learning_rate': 0.00029516936}
# I1108 19:30:06.552283 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.030407999,
#  'Loss/localization_loss': 0.006403667,
#  'Loss/regularization_loss': 0.024200333,
#  'Loss/total_loss': 0.061012,
#  'learning_rate': 0.00029516936}
# INFO:tensorflow:Step 192400 per-step time 0.378s
# I1108 19:30:44.375017 137794023396480 model_lib_v2.py:705] Step 192400 per-step time 0.378s
# INFO:tensorflow:{'Loss/classification_loss': 0.024093995,
#  'Loss/localization_loss': 0.004865296,
#  'Loss/regularization_loss': 0.024199773,
#  'Loss/total_loss': 0.053159066,
#  'learning_rate': 0.00028755903}
# I1108 19:30:44.375450 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.024093995,
#  'Loss/localization_loss': 0.004865296,
#  'Loss/regularization_loss': 0.024199773,
#  'Loss/total_loss': 0.053159066,
#  'learning_rate': 0.00028755903}
# INFO:tensorflow:Step 192500 per-step time 0.400s
# I1108 19:31:24.371659 137794023396480 model_lib_v2.py:705] Step 192500 per-step time 0.400s
# INFO:tensorflow:{'Loss/classification_loss': 0.02666884,
#  'Loss/localization_loss': 0.004118511,
#  'Loss/regularization_loss': 0.024199223,
#  'Loss/total_loss': 0.054986574,
#  'learning_rate': 0.00028005123}
# I1108 19:31:24.372199 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.02666884,
#  'Loss/localization_loss': 0.004118511,
#  'Loss/regularization_loss': 0.024199223,
#  'Loss/total_loss': 0.054986574,
#  'learning_rate': 0.00028005123}
# INFO:tensorflow:Step 192600 per-step time 0.418s
# I1108 19:32:06.190798 137794023396480 model_lib_v2.py:705] Step 192600 per-step time 0.418s
# INFO:tensorflow:{'Loss/classification_loss': 0.022356335,
#  'Loss/localization_loss': 0.005377354,
#  'Loss/regularization_loss': 0.02419869,
#  'Loss/total_loss': 0.05193238,
#  'learning_rate': 0.00027264116}
# I1108 19:32:06.191144 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.022356335,
#  'Loss/localization_loss': 0.005377354,
#  'Loss/regularization_loss': 0.02419869,
#  'Loss/total_loss': 0.05193238,
#  'learning_rate': 0.00027264116}
# INFO:tensorflow:Step 192700 per-step time 0.408s
# I1108 19:32:47.025869 137794023396480 model_lib_v2.py:705] Step 192700 per-step time 0.408s
# INFO:tensorflow:{'Loss/classification_loss': 0.026133088,
#  'Loss/localization_loss': 0.005047867,
#  'Loss/regularization_loss': 0.024198167,
#  'Loss/total_loss': 0.055379122,
#  'learning_rate': 0.00026533127}
# I1108 19:32:47.026233 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.026133088,
#  'Loss/localization_loss': 0.005047867,
#  'Loss/regularization_loss': 0.024198167,
#  'Loss/total_loss': 0.055379122,
#  'learning_rate': 0.00026533127}
# INFO:tensorflow:Step 192800 per-step time 0.397s
# I1108 19:33:26.725660 137794023396480 model_lib_v2.py:705] Step 192800 per-step time 0.397s
# INFO:tensorflow:{'Loss/classification_loss': 0.022724153,
#  'Loss/localization_loss': 0.004574356,
#  'Loss/regularization_loss': 0.02419766,
#  'Loss/total_loss': 0.05149617,
#  'learning_rate': 0.0002581191}
# I1108 19:33:26.726158 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.022724153,
#  'Loss/localization_loss': 0.004574356,
#  'Loss/regularization_loss': 0.02419766,
#  'Loss/total_loss': 0.05149617,
#  'learning_rate': 0.0002581191}
# INFO:tensorflow:Step 192900 per-step time 0.392s
# I1108 19:34:05.929531 137794023396480 model_lib_v2.py:705] Step 192900 per-step time 0.392s
# INFO:tensorflow:{'Loss/classification_loss': 0.021635728,
#  'Loss/localization_loss': 0.007888252,
#  'Loss/regularization_loss': 0.024197178,
#  'Loss/total_loss': 0.05372116,
#  'learning_rate': 0.00025100706}
# I1108 19:34:05.929936 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.021635728,
#  'Loss/localization_loss': 0.007888252,
#  'Loss/regularization_loss': 0.024197178,
#  'Loss/total_loss': 0.05372116,
#  'learning_rate': 0.00025100706}
# INFO:tensorflow:Step 193000 per-step time 0.397s
# I1108 19:34:45.546547 137794023396480 model_lib_v2.py:705] Step 193000 per-step time 0.397s
# INFO:tensorflow:{'Loss/classification_loss': 0.02742017,
#  'Loss/localization_loss': 0.004478044,
#  'Loss/regularization_loss': 0.024196701,
#  'Loss/total_loss': 0.056094915,
#  'learning_rate': 0.0002439928}
# I1108 19:34:45.547649 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.02742017,
#  'Loss/localization_loss': 0.004478044,
#  'Loss/regularization_loss': 0.024196701,
#  'Loss/total_loss': 0.056094915,
#  'learning_rate': 0.0002439928}
# INFO:tensorflow:Step 193100 per-step time 0.419s
# I1108 19:35:27.453967 137794023396480 model_lib_v2.py:705] Step 193100 per-step time 0.419s
# INFO:tensorflow:{'Loss/classification_loss': 0.030650837,
#  'Loss/localization_loss': 0.006233922,
#  'Loss/regularization_loss': 0.024196241,
#  'Loss/total_loss': 0.061081,
#  'learning_rate': 0.00023707867}
# I1108 19:35:27.454619 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.030650837,
#  'Loss/localization_loss': 0.006233922,
#  'Loss/regularization_loss': 0.024196241,
#  'Loss/total_loss': 0.061081,
#  'learning_rate': 0.00023707867}
# INFO:tensorflow:Step 193200 per-step time 0.404s
# I1108 19:36:07.908757 137794023396480 model_lib_v2.py:705] Step 193200 per-step time 0.404s
# INFO:tensorflow:{'Loss/classification_loss': 0.027359663,
#  'Loss/localization_loss': 0.006523593,
# ...
# INFO:tensorflow:Step 197400 per-step time 0.386s
# I1108 20:03:57.869429 137794023396480 model_lib_v2.py:705] Step 197400 per-step time 0.386s
# INFO:tensorflow:{'Loss/classification_loss': 0.02799858,
#  'Loss/localization_loss': 0.005772729,
#  'Loss/regularization_loss': 0.024186257,
#  'Loss/total_loss': 0.057957567,
#  'learning_rate': 3.369093e-05}
# I1108 20:03:57.869810 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.02799858,
#  'Loss/localization_loss': 0.005772729,
#  'Loss/regularization_loss': 0.024186257,
#  'Loss/total_loss': 0.057957567,
#  'learning_rate': 3.369093e-05}
# INFO:tensorflow:Step 197500 per-step time 0.362s
# I1108 20:04:34.044972 137794023396480 model_lib_v2.py:705] Step 197500 per-step time 0.362s
# INFO:tensorflow:{'Loss/classification_loss': 0.0253724,
#  'Loss/localization_loss': 0.0054900628,
#  'Loss/regularization_loss': 0.024186196,
#  'Loss/total_loss': 0.05504866,
#  'learning_rate': 3.1149386e-05}
# I1108 20:04:34.045366 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.0253724,
#  'Loss/localization_loss': 0.0054900628,
#  'Loss/regularization_loss': 0.024186196,
#  'Loss/total_loss': 0.05504866,
#  'learning_rate': 3.1149386e-05}
# INFO:tensorflow:Step 197600 per-step time 0.398s
# I1108 20:05:13.849178 137794023396480 model_lib_v2.py:705] Step 197600 per-step time 0.398s
# INFO:tensorflow:{'Loss/classification_loss': 0.025999269,
#  'Loss/localization_loss': 0.007871113,
#  'Loss/regularization_loss': 0.024186136,
#  'Loss/total_loss': 0.05805652,
#  'learning_rate': 2.870798e-05}
# I1108 20:05:13.849556 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.025999269,
#  'Loss/localization_loss': 0.007871113,
#  'Loss/regularization_loss': 0.024186136,
#  'Loss/total_loss': 0.05805652,
#  'learning_rate': 2.870798e-05}
# INFO:tensorflow:Step 197700 per-step time 0.404s
# I1108 20:05:54.266140 137794023396480 model_lib_v2.py:705] Step 197700 per-step time 0.404s
# INFO:tensorflow:{'Loss/classification_loss': 0.032454867,
#  'Loss/localization_loss': 0.005957442,
#  'Loss/regularization_loss': 0.02418608,
#  'Loss/total_loss': 0.06259839,
#  'learning_rate': 2.6364325e-05}
# I1108 20:05:54.266796 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.032454867,
#  'Loss/localization_loss': 0.005957442,
#  'Loss/regularization_loss': 0.02418608,
#  'Loss/total_loss': 0.06259839,
#  'learning_rate': 2.6364325e-05}
# INFO:tensorflow:Step 197800 per-step time 0.395s
# I1108 20:06:33.817409 137794023396480 model_lib_v2.py:705] Step 197800 per-step time 0.395s
# INFO:tensorflow:{'Loss/classification_loss': 0.024853239,
#  'Loss/localization_loss': 0.008107257,
#  'Loss/regularization_loss': 0.024186032,
#  'Loss/total_loss': 0.057146527,
#  'learning_rate': 2.4123192e-05}
# I1108 20:06:33.817816 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.024853239,
#  'Loss/localization_loss': 0.008107257,
#  'Loss/regularization_loss': 0.024186032,
#  'Loss/total_loss': 0.057146527,
#  'learning_rate': 2.4123192e-05}
# INFO:tensorflow:Step 197900 per-step time 0.372s
# I1108 20:07:11.001415 137794023396480 model_lib_v2.py:705] Step 197900 per-step time 0.372s
# INFO:tensorflow:{'Loss/classification_loss': 0.025667153,
#  'Loss/localization_loss': 0.007231897,
#  'Loss/regularization_loss': 0.024185989,
#  'Loss/total_loss': 0.05708504,
#  'learning_rate': 2.1979808e-05}
# I1108 20:07:11.001840 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.025667153,
#  'Loss/localization_loss': 0.007231897,
#  'Loss/regularization_loss': 0.024185989,
#  'Loss/total_loss': 0.05708504,
#  'learning_rate': 2.1979808e-05}
# INFO:tensorflow:Step 198000 per-step time 0.395s
# I1108 20:07:50.414619 137794023396480 model_lib_v2.py:705] Step 198000 per-step time 0.395s
# INFO:tensorflow:{'Loss/classification_loss': 0.022568366,
#  'Loss/localization_loss': 0.005106429,
#  'Loss/regularization_loss': 0.024185946,
#  'Loss/total_loss': 0.051860742,
#  'learning_rate': 1.993656e-05}
# I1108 20:07:50.414977 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.022568366,
#  'Loss/localization_loss': 0.005106429,
#  'Loss/regularization_loss': 0.024185946,
#  'Loss/total_loss': 0.051860742,
#  'learning_rate': 1.993656e-05}
# INFO:tensorflow:Step 198100 per-step time 0.417s
# I1108 20:08:32.153954 137794023396480 model_lib_v2.py:705] Step 198100 per-step time 0.417s
# INFO:tensorflow:{'Loss/classification_loss': 0.022509838,
#  'Loss/localization_loss': 0.004661098,
#  'Loss/regularization_loss': 0.024185913,
#  'Loss/total_loss': 0.05135685,
#  'learning_rate': 1.799345e-05}
# I1108 20:08:32.154613 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.022509838,
#  'Loss/localization_loss': 0.004661098,
#  'Loss/regularization_loss': 0.024185913,
#  'Loss/total_loss': 0.05135685,
#  'learning_rate': 1.799345e-05}
# INFO:tensorflow:Step 198200 per-step time 0.400s
# I1108 20:09:12.112478 137794023396480 model_lib_v2.py:705] Step 198200 per-step time 0.400s
# INFO:tensorflow:{'Loss/classification_loss': 0.025499074,
#  'Loss/localization_loss': 0.0064905705,
#  'Loss/regularization_loss': 0.024185877,
#  'Loss/total_loss': 0.056175523,
#  'learning_rate': 1.614809e-05}
# I1108 20:09:12.114686 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.025499074,
#  'Loss/localization_loss': 0.0064905705,
#  'Loss/regularization_loss': 0.024185877,
#  'Loss/total_loss': 0.056175523,
#  'learning_rate': 1.614809e-05}
# INFO:tensorflow:Step 198300 per-step time 0.378s
# I1108 20:09:49.934398 137794023396480 model_lib_v2.py:705] Step 198300 per-step time 0.378s
# INFO:tensorflow:{'Loss/classification_loss': 0.023689153,
#  'Loss/localization_loss': 0.0067492,
#  'Loss/regularization_loss': 0.024185847,
#  'Loss/total_loss': 0.0546242,
#  'learning_rate': 1.440525e-05}
# I1108 20:09:49.934755 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.023689153,
#  'Loss/localization_loss': 0.0067492,
#  'Loss/regularization_loss': 0.024185847,
#  'Loss/total_loss': 0.0546242,
#  'learning_rate': 1.440525e-05}
# INFO:tensorflow:Step 198400 per-step time 0.392s
# I1108 20:10:29.174977 137794023396480 model_lib_v2.py:705] Step 198400 per-step time 0.392s
# INFO:tensorflow:{'Loss/classification_loss': 0.027432386,
#  'Loss/localization_loss': 0.0066280053,
#  'Loss/regularization_loss': 0.02418582,
#  'Loss/total_loss': 0.05824621,
#  'learning_rate': 1.27601625e-05}
# I1108 20:10:29.175360 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.027432386,
#  'Loss/localization_loss': 0.0066280053,
#  'Loss/regularization_loss': 0.02418582,
#  'Loss/total_loss': 0.05824621,
#  'learning_rate': 1.27601625e-05}
# INFO:tensorflow:Step 198500 per-step time 0.411s
# I1108 20:11:10.331100 137794023396480 model_lib_v2.py:705] Step 198500 per-step time 0.411s
# INFO:tensorflow:{'Loss/classification_loss': 0.021106778,
#  'Loss/localization_loss': 0.0054377727,
#  'Loss/regularization_loss': 0.024185799,
#  'Loss/total_loss': 0.050730348,
#  'learning_rate': 1.1215209e-05}
# I1108 20:11:10.331748 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.021106778,
#  'Loss/localization_loss': 0.0054377727,
#  'Loss/regularization_loss': 0.024185799,
#  'Loss/total_loss': 0.050730348,
#  'learning_rate': 1.1215209e-05}
# INFO:tensorflow:Step 198600 per-step time 0.408s
# I1108 20:11:51.076165 137794023396480 model_lib_v2.py:705] Step 198600 per-step time 0.408s
# INFO:tensorflow:{'Loss/classification_loss': 0.02297096,
#  'Loss/localization_loss': 0.0044533466,
#  'Loss/regularization_loss': 0.024185773,
#  'Loss/total_loss': 0.05161008,
#  'learning_rate': 9.768009e-06}
# I1108 20:11:51.076547 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.02297096,
#  'Loss/localization_loss': 0.0044533466,
#  'Loss/regularization_loss': 0.024185773,
#  'Loss/total_loss': 0.05161008,
#  'learning_rate': 9.768009e-06}
# INFO:tensorflow:Step 198700 per-step time 0.376s
# I1108 20:12:28.711529 137794023396480 model_lib_v2.py:705] Step 198700 per-step time 0.376s
# INFO:tensorflow:{'Loss/classification_loss': 0.025068862,
#  'Loss/localization_loss': 0.0063018175,
#  'Loss/regularization_loss': 0.02418576,
#  'Loss/total_loss': 0.05555644,
#  'learning_rate': 8.423328e-06}
# I1108 20:12:28.711905 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.025068862,
#  'Loss/localization_loss': 0.0063018175,
#  'Loss/regularization_loss': 0.02418576,
#  'Loss/total_loss': 0.05555644,
#  'learning_rate': 8.423328e-06}
# INFO:tensorflow:Step 198800 per-step time 0.375s
# I1108 20:13:06.218958 137794023396480 model_lib_v2.py:705] Step 198800 per-step time 0.375s
# INFO:tensorflow:{'Loss/classification_loss': 0.030739032,
#  'Loss/localization_loss': 0.0060538463,
#  'Loss/regularization_loss': 0.024185745,
#  'Loss/total_loss': 0.06097862,
#  'learning_rate': 7.176399e-06}
# I1108 20:13:06.219312 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.030739032,
#  'Loss/localization_loss': 0.0060538463,
#  'Loss/regularization_loss': 0.024185745,
#  'Loss/total_loss': 0.06097862,
#  'learning_rate': 7.176399e-06}
# INFO:tensorflow:Step 198900 per-step time 0.400s
# I1108 20:13:46.194846 137794023396480 model_lib_v2.py:705] Step 198900 per-step time 0.400s
# INFO:tensorflow:{'Loss/classification_loss': 0.02359105,
#  'Loss/localization_loss': 0.0071713706,
#  'Loss/regularization_loss': 0.024185728,
#  'Loss/total_loss': 0.05494815,
#  'learning_rate': 6.03199e-06}
# I1108 20:13:46.195409 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.02359105,
#  'Loss/localization_loss': 0.0071713706,
#  'Loss/regularization_loss': 0.024185728,
#  'Loss/total_loss': 0.05494815,
#  'learning_rate': 6.03199e-06}
# INFO:tensorflow:Step 199000 per-step time 0.389s
# I1108 20:14:25.047046 137794023396480 model_lib_v2.py:705] Step 199000 per-step time 0.389s
# INFO:tensorflow:{'Loss/classification_loss': 0.02473565,
#  'Loss/localization_loss': 0.005611356,
#  'Loss/regularization_loss': 0.024185719,
#  'Loss/total_loss': 0.054532725,
#  'learning_rate': 4.9853325e-06}
# I1108 20:14:25.047570 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.02473565,
#  'Loss/localization_loss': 0.005611356,
#  'Loss/regularization_loss': 0.024185719,
#  'Loss/total_loss': 0.054532725,
#  'learning_rate': 4.9853325e-06}
# INFO:tensorflow:Step 199100 per-step time 0.399s
# I1108 20:15:04.939412 137794023396480 model_lib_v2.py:705] Step 199100 per-step time 0.399s
# INFO:tensorflow:{'Loss/classification_loss': 0.021927675,
#  'Loss/localization_loss': 0.0055419006,
#  'Loss/regularization_loss': 0.02418571,
#  'Loss/total_loss': 0.051655285,
#  'learning_rate': 4.0364266e-06}
# I1108 20:15:04.939821 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.021927675,
#  'Loss/localization_loss': 0.0055419006,
#  'Loss/regularization_loss': 0.02418571,
#  'Loss/total_loss': 0.051655285,
#  'learning_rate': 4.0364266e-06}
# INFO:tensorflow:Step 199200 per-step time 0.384s
# I1108 20:15:43.385306 137794023396480 model_lib_v2.py:705] Step 199200 per-step time 0.384s
# INFO:tensorflow:{'Loss/classification_loss': 0.02226782,
#  'Loss/localization_loss': 0.00598961,
#  'Loss/regularization_loss': 0.024185706,
#  'Loss/total_loss': 0.052443136,
#  'learning_rate': 3.1900406e-06}
# I1108 20:15:43.385667 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.02226782,
#  'Loss/localization_loss': 0.00598961,
#  'Loss/regularization_loss': 0.024185706,
#  'Loss/total_loss': 0.052443136,
#  'learning_rate': 3.1900406e-06}
# INFO:tensorflow:Step 199300 per-step time 0.392s
# I1108 20:16:22.616039 137794023396480 model_lib_v2.py:705] Step 199300 per-step time 0.392s
# INFO:tensorflow:{'Loss/classification_loss': 0.02984235,
#  'Loss/localization_loss': 0.005883058,
#  'Loss/regularization_loss': 0.024185698,
#  'Loss/total_loss': 0.059911106,
#  'learning_rate': 2.4414062e-06}
# I1108 20:16:22.616431 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.02984235,
#  'Loss/localization_loss': 0.005883058,
#  'Loss/regularization_loss': 0.024185698,
#  'Loss/total_loss': 0.059911106,
#  'learning_rate': 2.4414062e-06}
# INFO:tensorflow:Step 199400 per-step time 0.391s
# I1108 20:17:01.710248 137794023396480 model_lib_v2.py:705] Step 199400 per-step time 0.391s
# INFO:tensorflow:{'Loss/classification_loss': 0.025296202,
#  'Loss/localization_loss': 0.0042646774,
#  'Loss/regularization_loss': 0.024185693,
#  'Loss/total_loss': 0.053746574,
#  'learning_rate': 1.7952918e-06}
# I1108 20:17:01.710654 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.025296202,
#  'Loss/localization_loss': 0.0042646774,
#  'Loss/regularization_loss': 0.024185693,
#  'Loss/total_loss': 0.053746574,
#  'learning_rate': 1.7952918e-06}
# INFO:tensorflow:Step 199500 per-step time 0.372s
# I1108 20:17:38.871166 137794023396480 model_lib_v2.py:705] Step 199500 per-step time 0.372s
# INFO:tensorflow:{'Loss/classification_loss': 0.021170886,
#  'Loss/localization_loss': 0.0044609644,
#  'Loss/regularization_loss': 0.024185691,
#  'Loss/total_loss': 0.04981754,
#  'learning_rate': 1.2469292e-06}
# I1108 20:17:38.871553 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.021170886,
#  'Loss/localization_loss': 0.0044609644,
#  'Loss/regularization_loss': 0.024185691,
#  'Loss/total_loss': 0.04981754,
#  'learning_rate': 1.2469292e-06}
# INFO:tensorflow:Step 199600 per-step time 0.409s
# I1108 20:18:19.720888 137794023396480 model_lib_v2.py:705] Step 199600 per-step time 0.409s
# INFO:tensorflow:{'Loss/classification_loss': 0.031593915,
#  'Loss/localization_loss': 0.0075951177,
#  'Loss/regularization_loss': 0.024185687,
#  'Loss/total_loss': 0.06337472,
#  'learning_rate': 7.9631803e-07}
# I1108 20:18:19.721297 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.031593915,
#  'Loss/localization_loss': 0.0075951177,
#  'Loss/regularization_loss': 0.024185687,
#  'Loss/total_loss': 0.06337472,
#  'learning_rate': 7.9631803e-07}
# INFO:tensorflow:Step 199700 per-step time 0.404s
# I1108 20:19:00.164239 137794023396480 model_lib_v2.py:705] Step 199700 per-step time 0.404s
# INFO:tensorflow:{'Loss/classification_loss': 0.025349991,
#  'Loss/localization_loss': 0.005088827,
#  'Loss/regularization_loss': 0.024185687,
#  'Loss/total_loss': 0.054624505,
#  'learning_rate': 4.4822693e-07}
# I1108 20:19:00.164692 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.025349991,
#  'Loss/localization_loss': 0.005088827,
#  'Loss/regularization_loss': 0.024185687,
#  'Loss/total_loss': 0.054624505,
#  'learning_rate': 4.4822693e-07}
# INFO:tensorflow:Step 199800 per-step time 0.389s
# I1108 20:19:39.126374 137794023396480 model_lib_v2.py:705] Step 199800 per-step time 0.389s
# INFO:tensorflow:{'Loss/classification_loss': 0.032848004,
#  'Loss/localization_loss': 0.013087,
#  'Loss/regularization_loss': 0.024185687,
#  'Loss/total_loss': 0.07012069,
#  'learning_rate': 2.002716e-07}
# I1108 20:19:39.130575 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.032848004,
#  'Loss/localization_loss': 0.013087,
#  'Loss/regularization_loss': 0.024185687,
#  'Loss/total_loss': 0.07012069,
#  'learning_rate': 2.002716e-07}
# INFO:tensorflow:Step 199900 per-step time 0.372s
# I1108 20:20:16.313922 137794023396480 model_lib_v2.py:705] Step 199900 per-step time 0.372s
# INFO:tensorflow:{'Loss/classification_loss': 0.029267918,
#  'Loss/localization_loss': 0.010687797,
#  'Loss/regularization_loss': 0.024185687,
#  'Loss/total_loss': 0.06414141,
#  'learning_rate': 5.00679e-08}
# I1108 20:20:16.314289 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.029267918,
#  'Loss/localization_loss': 0.010687797,
#  'Loss/regularization_loss': 0.024185687,
#  'Loss/total_loss': 0.06414141,
#  'learning_rate': 5.00679e-08}
# INFO:tensorflow:Step 200000 per-step time 0.398s
# I1108 20:20:56.099404 137794023396480 model_lib_v2.py:705] Step 200000 per-step time 0.398s
# INFO:tensorflow:{'Loss/classification_loss': 0.030176725,
#  'Loss/localization_loss': 0.007741006,
#  'Loss/regularization_loss': 0.024185687,
#  'Loss/total_loss': 0.06210342,
#  'learning_rate': 0.0}
# I1108 20:20:56.099762 137794023396480 model_lib_v2.py:708] {'Loss/classification_loss': 0.030176725,
#  'Loss/localization_loss': 0.007741006,
#  'Loss/regularization_loss': 0.024185687,
#  'Loss/total_loss': 0.06210342,
#  'learning_rate': 0.0}

# %%
# !rm -r /content/mainmodel/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model

# %%
# !python3 /content/models/research/object_detection/model_main_tf2.py --model_dir=/content/drive/MyDrive/obj_detection_training/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/ --pipeline_config_path=/content/mainmodel/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config --checkpoint_dir=/content/mainmodel/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint
# Out:
# 2023-11-08 20:34:59.440459: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-08 20:34:59.440503: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-08 20:34:59.440541: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-08 20:34:59.448980: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-08 20:35:01.588477: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-11-08 20:35:06.554811: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-08 20:35:06.826241: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-08 20:35:06.826602: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W1108 20:35:06.832019 133134554600576 model_lib_v2.py:1089] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I1108 20:35:06.832268 133134554600576 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I1108 20:35:06.832377 133134554600576 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I1108 20:35:06.832461 133134554600576 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# W1108 20:35:06.832569 133134554600576 model_lib_v2.py:1106] Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# 2023-11-08 20:35:06.838256: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-08 20:35:06.838609: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-08 20:35:06.838889: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-08 20:35:09.478296: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-08 20:35:09.478779: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-08 20:35:09.478977: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-11-08 20:35:09.479134: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-08 20:35:09.479330: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13692 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# INFO:tensorflow:Reading unweighted datasets: ['/content/test.record']
# I1108 20:35:09.559400 133134554600576 dataset_builder.py:162] Reading unweighted datasets: ['/content/test.record']
# INFO:tensorflow:Reading record datasets for input file: ['/content/test.record']
# I1108 20:35:09.559677 133134554600576 dataset_builder.py:79] Reading record datasets for input file: ['/content/test.record']
# INFO:tensorflow:Number of filenames to read: 1
# I1108 20:35:09.559791 133134554600576 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W1108 20:35:09.559871 133134554600576 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /content/models/research/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W1108 20:35:09.564265 133134554600576 deprecation.py:50] From /content/models/research/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /content/models/research/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W1108 20:35:09.594541 133134554600576 deprecation.py:50] From /content/models/research/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1260: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W1108 20:35:15.248873 133134554600576 deprecation.py:50] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1260: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1260: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1108 20:35:16.304421 133134554600576 deprecation.py:50] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1260: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Waiting for new checkpoint at /content/mainmodel/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint
# I1108 20:35:18.608789 133134554600576 checkpoint_utils.py:168] Waiting for new checkpoint at /content/mainmodel/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint
# INFO:tensorflow:Found new checkpoint at /content/mainmodel/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-386
# I1108 20:35:18.609602 133134554600576 checkpoint_utils.py:177] Found new checkpoint at /content/mainmodel/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-386
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# I1108 20:35:23.448890 133134554600576 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I1108 20:35:38.612082 133134554600576 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# 2023-11-08 20:35:45.421293: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8900
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1260: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1108 20:35:51.640313 133134554600576 deprecation.py:50] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1260: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Finished eval step 0
# I1108 20:35:51.677199 133134554600576 model_lib_v2.py:966] Finished eval step 0
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py:460: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# W1108 20:35:51.934828 133134554600576 deprecation.py:50] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py:460: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# INFO:tensorflow:Finished eval step 100
# I1108 20:35:59.245777 133134554600576 model_lib_v2.py:966] Finished eval step 100
# INFO:tensorflow:Finished eval step 200
# I1108 20:36:03.755842 133134554600576 model_lib_v2.py:966] Finished eval step 200
# INFO:tensorflow:Finished eval step 300
# I1108 20:36:10.268603 133134554600576 model_lib_v2.py:966] Finished eval step 300
# INFO:tensorflow:Performing evaluation on 399 images.
# I1108 20:36:40.882674 133134554600576 coco_evaluation.py:293] Performing evaluation on 399 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I1108 20:36:40.885832 133134554600576 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.03s)
# I1108 20:36:40.913165 133134554600576 coco_tools.py:138] DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=3.90s).
# Accumulating evaluation results...
# DONE (t=0.62s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.921
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.990
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.960
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.033
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.573
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.953
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.312
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.938
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.939
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.120
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.632
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.969
# INFO:tensorflow:Eval metrics at step 200000
# I1108 20:36:45.513864 133134554600576 model_lib_v2.py:1015] Eval metrics at step 200000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.920852
# I1108 20:36:45.528980 133134554600576 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP: 0.920852
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 0.989782
# I1108 20:36:45.530989 133134554600576 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.50IOU: 0.989782
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.960050
# I1108 20:36:45.532725 133134554600576 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.960050
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): 0.033182
# I1108 20:36:45.534365 133134554600576 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (small): 0.033182
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): 0.572664
# I1108 20:36:45.535976 133134554600576 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (medium): 0.572664
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): 0.953317
# I1108 20:36:45.537755 133134554600576 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (large): 0.953317
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.312460
# I1108 20:36:45.539537 133134554600576 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@1: 0.312460
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.938498
# I1108 20:36:45.541140 133134554600576 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@10: 0.938498
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.939058
# I1108 20:36:45.542804 133134554600576 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100: 0.939058
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): 0.120000
# I1108 20:36:45.544497 133134554600576 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (small): 0.120000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): 0.631633
# I1108 20:36:45.546263 133134554600576 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (medium): 0.631633
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.968842
# I1108 20:36:45.548111 133134554600576 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (large): 0.968842
# INFO:tensorflow:	+ Loss/localization_loss: 0.007444
# I1108 20:36:45.549481 133134554600576 model_lib_v2.py:1018] 	+ Loss/localization_loss: 0.007444
# INFO:tensorflow:	+ Loss/classification_loss: 0.030835
# I1108 20:36:45.550864 133134554600576 model_lib_v2.py:1018] 	+ Loss/classification_loss: 0.030835
# INFO:tensorflow:	+ Loss/regularization_loss: 0.024186
# I1108 20:36:45.552134 133134554600576 model_lib_v2.py:1018] 	+ Loss/regularization_loss: 0.024186
# INFO:tensorflow:	+ Loss/total_loss: 0.062465
# I1108 20:36:45.553419 133134554600576 model_lib_v2.py:1018] 	+ Loss/total_loss: 0.062465
# INFO:tensorflow:Exiting evaluation at step 200000
# I1108 20:36:45.629015 133134554600576 model_lib_v2.py:1168] Exiting evaluation at step 200000

# %%
# !python3 /content/models/research/object_detection/exporter_main_v2.py \
    --input_type image_tensor \
    --pipeline_config_path /content/mainmodel/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config \
    --trained_checkpoint_dir /content/mainmodel/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint \
    --output_directory hand_inference_graph

# %%
# !zip -r hand_inference_graph.zip hand_inference_graph/

# %%
# !pip install roboflow
# !mkdir /content/datasets
# %cd /content/datasets
from roboflow import Roboflow
rf = Roboflow(api_key="8O0d3piVDubPgWzft4ha")

project = rf.workspace("bdbi").project("image-annotation-lxsso")
dataset = project.version(5).download("yolov8")

# %%
# %cd /content
# Out:
# /content

# %%
# from utils import detector_utils as detector_utils
import cv2
import tensorflow as tf
import datetime
import argparse
import numpy as np
import time
import dataset_gen
from object_detection.utils import config_util
from object_detection.builders import model_builder
import os
from object_detection.utils import visualization_utils as viz_utils
from object_detection.utils import label_map_util
from tensorflow import squeeze

# detection_graph, sess = detector_utils.load_inference_graph()
# Loading saved mode.
# model = tf.saved_model.load("hand_inference_graph/saved_model")
PATH_TO_MODEL_DIR = "/content/mainmodel/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8"
PATH_TO_CFG = PATH_TO_MODEL_DIR + "/pipeline.config"
PATH_TO_CKPT = PATH_TO_MODEL_DIR + "/checkpoint"
CKPT_NUM = 386

print('Loading model... ', end='')
start_time = time.time()

# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(PATH_TO_CFG)
model_config = configs['model']
detection_model = model_builder.build(model_config=model_config, is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(PATH_TO_CKPT, f'ckpt-{CKPT_NUM}')).expect_partial()

@tf.function
def detect_fn(image):
    """Detect objects in image."""

    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)

    return detections

from google.colab.patches import cv2_imshow
path_to_train_images = '/content/datasets/Image-Annotation-5/train/images'
# path_to_train_labels = '/content/Image-Annotation-5/train/labels'
path_to_test_images = '/content/datasets/Image-Annotation-5/test/images'
# path_to_test_labels = '/content/Image-Annotation-5/test/labels'
path_to_val_images = '/content/datasets/Image-Annotation-5/valid/images'
# path_to_val_labels = '/content/Image-Annotation-5/valid/labels'
category_index = {0: {'id': 1, 'name': 'hand'}}

# def image_resize(image, width = None, height = None, inter = cv2.INTER_AREA):
#     # initialize the dimensions of the image to be resized and
#     # grab the image size
#     dim = None
#     (h, w) = image.shape[:2]
#     if h>w:


#     # if both the width and height are None, then return the
#     # original image
#     if width is None and height is None:
#         return image

#     # check to see if the width is None
#     if width is None:
#         # calculate the ratio of the height and construct the
#         # dimensions
#         r = height / float(h)
#         dim = (int(w * r), height)

#     # otherwise, the height is None
#     else:
#         # calculate the ratio of the width and construct the
#         # dimensions
#         r = width / float(w)
#         dim = (width, int(h * r))

#     # resize the image
#     resized = cv2.resize(image, dim, interpolation = inter)

#     # return the resized image
#     return resized


if __name__ == '__main__':

    # parser = argparse.ArgumentParser()
    # parser.add_argument(
    #     '-sth',
    #     '--scorethreshold',
    #     dest='score_thresh',
    #     type=float,
    #     default=0.2,
    #     help='Score threshold for displaying bounding boxes')

    # args = parser.parse_args()

    start_time = datetime.datetime.now()
    num_frames = 0
    im_width, im_height = (512, 513)
    # max number of hands we want to detect/track
    num_hands_detect = 1

    #cv2.namedWindow('Single-Threaded Detection', cv2.WINDOW_NORMAL)

    for image_path in dataset_gen.generate_stream(path_to_val_images):
        # Expand dimensions since the model expects images to have shape: [1, None, None, 3]

        # Pre-processing image.
        image1 = tf.image.decode_image(open(image_path, 'rb').read(), channels=3)
        image = tf.expand_dims(image1, 0)
        image = tf.image.resize_with_pad(image, 640, 640)
        # image_np = cv2.imread(image_path)
        # image_np = cv2.cvtColor(image_np, cv2.COLOR_BGR2RGB)
        detections = detect_fn(image)
        bbox = detections['detection_boxes'][0][0]
        bclass = detections['detection_classes'][0][0]
        bscore = detections['detection_scores'][0][0]

        print(bbox, bclass, bscore)

        finalbox = []
        class_label = None
        image_display = None
        if bscore >= 0.2:
            y_min = int(bbox[0] * im_height)
            x_min = int(bbox[1] * im_width)
            y_max = int(bbox[2] * im_height)
            x_max = int(bbox[3] * im_width)
            class_label = category_index[int(bclass)]['name']
            finalbox = [x_min, y_min, x_max, y_max, class_label, float(bscore)]
        # return (bbox, class_labels)

        # det_boxes, class_labels = ExtractBBoxes(bboxes, bclasses, bscores, im_width, im_height)
            print(finalbox)
            print(class_label)


            # image_np = cv2.flip(image_np, 1)
            # try:
            #     image_np = cv2.cvtColor(image_np, cv2.COLOR_BGR2RGB)
            # except:
            #     print("Error converting to RGB")

            # Actual detection. Variable boxes contains the bounding box cordinates for hands detected,
            # while scores contains the confidence for each of these boxes.
            # Hint: If len(boxes) > 1 , you may assume you have found atleast one hand (within your score threshold)

            # # draw bounding boxes on frame
            # detector_utils.draw_box_on_image(num_hands_detect, args.score_thresh,
            #                                  scores, boxes, im_width, im_height,
            #                                  image_np, 0.75)

            p1x = p2x = p1y = p2y = None
            height = width = None
            p1xbox = p2xbox = p1ybox = p2ybox = None
            (left, right, top, bottom) = (finalbox[0], finalbox[2], finalbox[1], finalbox[3])
            padding_percent = 0.75
            p1x = max(0, int(left) - int(left*padding_percent//2))
            p1y = max(0, int(top) - int(top*padding_percent//2))
            p2x = min(640, int(right) + int(right*padding_percent//2))
            p2y = min(640, int(bottom) + int(bottom*padding_percent//2))

            height = p2y - p1y
            width = p2x - p1x

            p1xbox = int(left*padding_percent//2)
            p2xbox = width - int(right*padding_percent//2)
            p1ybox = int(top*padding_percent//2)
            p2ybox = height - int(bottom*padding_percent//2)

            # print(squeeze(image).numpy().astype(np.uint8))
            image_np = cv2.cvtColor(tf.image.resize_with_pad(image1, 640, 640).numpy(), cv2.COLOR_RGB2BGR)

            #cv2_imshow(image_np)

            # (p1x, p1y, p2x, p2y) = (p1xbox, p1ybox, p2xbox, p2ybox)
            image_display = image_np[p1y:p2y, p1x:p2x]
        else:
            image_display = cv2.imread(image_path)

        # (p1x, p1y, p2x, p2y), image_display = detector_utils.get_image_cropped(num_hands_detect, args.score_thresh,
        #                                  scores, boxes, im_width, im_height,
        #                                  image_np, 0.75)
        # image_display = cv2.cvtColor(image_display, cv2.COLOR_RGB2BGR)
        # cv2.rectangle(image_display, (p1x, p1y), (p2x, p2y), (77, 255, 9), 3, 1)

        # Calculate Frames per second (FPS)
        num_frames += 1
        elapsed_time = (datetime.datetime.now() - start_time).total_seconds()
        fps = num_frames / elapsed_time

        if (finalbox is not None):
            # cv2.drawContours(image_np, contours=(77, 255, 9))
            # image_display = cv2.cvtColor(image_display, cv2.RGB2BGR)
            cv2_imshow(image_display)

            # if cv2.waitKey(25) & 0xFF == ord('q'):
            #     cv2.destroyAllWindows()
            #     break

            dataset_gen.saveImage(image_display, '/content/Image-Cropped/valid/images', image_path.split('/')[-1])
        else:
            print("frames processed: ", num_frames, "elapsed time: ",
                  elapsed_time, "fps: ", str(int(fps)))
